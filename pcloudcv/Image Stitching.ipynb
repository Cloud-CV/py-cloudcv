# %% [markdown]
# Start by importing PCloudCV module to run Python API for cloudcv

# %%
from pcloudcv import PCloudCV
from IPython.display import display
from IPython.display import display_pretty, display_html, display_jpeg, display_png, display_json, display_latex, display_svg
from IPython.display import Image
from IPython.display import HTML
import utility.job as uj
# Out:
# Added Path: /home/parallels/workspace/pcloudcv/pcloudcv

# %%
import os
config_path = os.path.join(os.getcwd(), 'config.json') #full path of the config.json file
dict = {'exec': 'ImageStitch'}

# %% [markdown]
# Starting the CloudCV is as easy initializing the class with the config file path, dictionary containing parameters and a flag specifying whether to login through google or not.

# %%
p = PCloudCV(config_path, dict, True)
p.start()
# Out:
# INFO:cherrypy.error:[19/Feb/2015:22:52:32] ENGINE Bus STARTING
# CherryPy Checker:
# The Application mounted at '' has an empty config.
#
# INFO:cherrypy.error:[19/Feb/2015:22:52:32] ENGINE Started monitor thread 'Autoreloader'.
# INFO:cherrypy.error:[19/Feb/2015:22:52:32] ENGINE Started monitor thread '_TimeoutMonitor'.
# /home/parallels/workspace/pcloudcv/pcloudcv/config.cfg
# 2eb315c2-ae39-11e4-b6e7-22000aecbe9d
# User Authenticated
# Welcome harsh
# Starting Listening to Redis Channel for HTTP Post Requests
# INFO:cherrypy.error:[19/Feb/2015:22:52:33] ENGINE Serving on http://127.0.0.1:8000
# INFO:cherrypy.error:[19/Feb/2015:22:52:33] ENGINE Bus STARTED
# Listening to Redis Channel
#
# Starting Socket Connection Thread
#
# Connected using websockets
# SocketID:  1IQzubM_yBJn8c9IoFIw
# Starting Post Request
# rfdHYHTGY7945jJdu8ivxloKLB5R1iwv
# rfdHYHTGY7945jJdu8ivxloKLB5R1iwv
# Resized image already present in the directory
# Resized image already present in the directory
# Resized image already present in the directory
# Resized image already present in the directory
# Resized image already present in the directory
# Resized image already present in the directory
# No of files to be uploaded:  6
# Source Path: local: /home/parallels/Public/ImageStitch
#
# Executable: ImageStitch
#
# Executable Params: {u'warp': u'plane'}
#
# SocketID:  1IQzubM_yBJn8c9IoFIw
# Starting The POST request
#
# Server: Post Request Recieved
# Processing files
# Info:   Please wait while CloudCV runs your job request
#
# Files Stored. Waiting for one of the worker nodes to handle this request
#
# Exiting From the Post Request Thread
#
# {u'count': 6, u'result_path': u'/home/ubuntu/cloudcv/cloudcv17/cloudcv17/media/pictures/2eb315c2-ae39-11e4-b6e7-22000aecbe9d/xhM9g4omoYMTucATxVjrJ6', u'image_path': u'/home/ubuntu/cloudcv/cloudcv17/cloudcv17/media/pictures/2eb315c2-ae39-11e4-b6e7-22000aecbe9d/xhM9g4omoYMTucATxVjrJ6', u'exec': u'ImageStitch', u'url': u'/media/pictures/2eb315c2-ae39-11e4-b6e7-22000aecbe9d/xhM9g4omoYMTucATxVjrJ6', u'socketid': u'1IQzubM_yBJn8c9IoFIw', u'dropbox_token': None, u'userid': u'2eb315c2-ae39-11e4-b6e7-22000aecbe9d', u'jobid': u'xhM9g4omoYMTucATxVjrJ6', u'source_type': u'local', u'token': u'rfdHYHTGY7945jJdu8ivxloKLB5R1iwv', u'params': u"{u'warp': u'plane'}", u'dir': u'/home/ubuntu/cloudcv/cloudcv17/cloudcv17/media/pictures/2eb315c2-ae39-11e4-b6e7-22000aecbe9d/xhM9g4omoYMTucATxVjrJ6'}
# GRAPHLAB_SUBNET_ID/GRAPHLAB_SUBNET_MASK environment variables not defined.
# Using default values
#
# Subnet ID: 0.0.0.0
#
# Subnet Mask: 0.0.0.0
#
# Will find first IPv4 non-loopback address matching the subnet
#
# INFO:     dc_init_from_mpi.cpp(init_param_from_mpi:51): Will Listen on: 10.150.71.117:55559
#
# INFO:     dc.cpp(distributed_control:124): Distributed Control Initialized from MPI
#
# INFO:     dc_tcp_comm.cpp(open_listening:411): Proc 0 listening on 55559
# INFO:     dc_tcp_comm.cpp(connect:432): Trying to connect from 0 -> 0 on port 55559
#
# INFO:     dc_tcp_comm.cpp(connect:435): Destination IP = 10.150.71.117
#
# INFO:     dc_tcp_comm.cpp(connect:467): connection from 0 to 0 established.
#
# INFO:     dc_tcp_comm.cpp(accept_handler:487): Listening thread launched.
#
# INFO:     dc_tcp_comm.cpp(accept_handler:493): Accepting....
#
# INFO:     dc_tcp_comm.cpp(accept_handler:498): Accepted
#
# INFO:     dc_tcp_comm.cpp(new_socket:375): Incoming connection from 10.150.71.117
#
# INFO:     dc_tcp_comm.cpp(new_socket:384): Proc 0 accepted connection from machine 0
#
# INFO:     dc_tcp_comm.cpp(accept_handler:548): Listening thread quitting
#
# INFO:     dc.cpp(init:571): TCP Communication layer constructed.
#
# INFO:     dc.cpp(init:573): Cluster of 1 instances created.
#
# INFO:     dc_tcp_comm.cpp(receive_loop:588): Receive loop Started
#
# INFO:     dc_tcp_comm.cpp(send_loop:647): Send loop Started
#
# ncpus:          6
#
# engine:         async
# scheduler:
# img_dir:        /home/ubuntu/cloudcv/cloudcv17/cloudcv17/media/pictures/2eb315c2-ae39-11e4-b6e7-22000aecbe9d/xhM9g4omoYMTucATxVjrJ6
#
# work_megapix:   0.6
# verbose:        1
#
# INFO:     distributed_graph.hpp(set_ingress_method:3201): Automatically determine ingress method: grid
#
# INFO:     stitch_main.hpp(graph_loader:75): Process: 0/1 picked image: /home/ubuntu/cloudcv/cloudcv17/cloudcv17/media/pictures/2eb315c2-ae39-11e4-b6e7-22000aecbe9d/xhM9g4omoYMTucATxVjrJ6/P1020358.jpg
#
# INFO:     stitch_main.hpp(graph_loader:75): Process: 0/1 picked image: /home/ubuntu/cloudcv/cloudcv17/cloudcv17/media/pictures/2eb315c2-ae39-11e4-b6e7-22000aecbe9d/xhM9g4omoYMTucATxVjrJ6/P1020359.jpg
#
# INFO:     stitch_main.hpp(graph_loader:75): Process: 0/1 picked image: /home/ubuntu/cloudcv/cloudcv17/cloudcv17/media/pictures/2eb315c2-ae39-11e4-b6e7-22000aecbe9d/xhM9g4omoYMTucATxVjrJ6/P1020360.jpg
#
# INFO:     stitch_main.hpp(graph_loader:75): Process: 0/1 picked image: /home/ubuntu/cloudcv/cloudcv17/cloudcv17/media/pictures/2eb315c2-ae39-11e4-b6e7-22000aecbe9d/xhM9g4omoYMTucATxVjrJ6/P1020361.jpg
#
# INFO:     stitch_main.hpp(graph_loader:75): Process: 0/1 picked image: /home/ubuntu/cloudcv/cloudcv17/cloudcv17/media/pictures/2eb315c2-ae39-11e4-b6e7-22000aecbe9d/xhM9g4omoYMTucATxVjrJ6/P1020363.jpg
#
# INFO:     stitch_main.hpp(graph_loader:75): Process: 0/1 picked image: /home/ubuntu/cloudcv/cloudcv17/cloudcv17/media/pictures/2eb315c2-ae39-11e4-b6e7-22000aecbe9d/xhM9g4omoYMTucATxVjrJ6/P1020366.jpg
#
# INFO:     stitch_main.hpp(graph_loader:104): Adding edge: (0,1)
#
# INFO:     stitch_main.hpp(graph_loader:104): Adding edge: (0,2)
#
# INFO:     stitch_main.hpp(graph_loader:104): Adding edge: (0,3)
#
# INFO:     stitch_main.hpp(graph_loader:104): Adding edge: (0,4)
#
# INFO:     stitch_main.hpp(graph_loader:104): Adding edge: (0,5)
#
# INFO:     stitch_main.hpp(graph_loader:104): Adding edge: (1,2)
#
# INFO:     stitch_main.hpp(graph_loader:104): Adding edge: (1,3)
#
# INFO:     stitch_main.hpp(graph_loader:104): Adding edge: (1,4)
#
# INFO:     stitch_main.hpp(graph_loader:104): Adding edge: (1,5)
#
# INFO:     stitch_main.hpp(graph_loader:104): Adding edge: (2,3)
#
# INFO:     stitch_main.hpp(graph_loader:104): Adding edge: (2,4)
#
# INFO:     stitch_main.hpp(graph_loader:104): Adding edge: (2,5)
#
# INFO:     stitch_main.hpp(graph_loader:104): Adding edge: (3,4)
#
# INFO:     stitch_main.hpp(graph_loader:104): Adding edge: (3,5)
#
# INFO:     stitch_main.hpp(graph_loader:104): Adding edge: (4,5)
#
# INFO:     distributed_graph.hpp(finalize:702): Distributed graph: enter finalize
#
# INFO:     distributed_ingress_base.hpp(finalize:199): Finalizing Graph...
#
# INFO:     memory_info.cpp(log_usage:90): Memory Info: Post Flush
#
# 	 Heap: 10 MB
#
# 	 Allocated: 5.53385 MB
#
# INFO:     distributed_ingress_base.hpp(finalize:259): Graph Finalize: constructing local graph
#
# INFO:     memory_info.cpp(log_usage:90): Memory Info: Finished populating local graph.
#
# 	 Heap: 10 MB
#
# 	 Allocated: 5.54589 MB
#
# INFO:     distributed_ingress_base.hpp(finalize:304): Graph Finalize: finalizing local graph.
#
# INFO:     dynamic_local_graph.hpp(finalize:339): Graph finalized in 0.064653 secs
# INFO:     distributed_ingress_base.hpp(finalize:307): Local graph info:
#
# 	 nverts: 6
#
# 	 nedges: 15
# INFO:     memory_info.cpp(log_usage:90): Memory Info: Finished finalizing local graph.
#
# 	 Heap: 10 MB
#
# 	 Allocated: 5.55146 MB
#
# INFO:     memory_info.cpp(log_usage:90): Memory Info: Finished adding vertex data
#
# 	 Heap: 10 MB
#
# 	 Allocated: 5.54853 MB
#
# INFO:     memory_info.cpp(log_usage:90): Memory Info: Finihsed allocating lvid2record
#
# 	 Heap: 10 MB
#
# 	 Allocated: 5.54194 MB
#
# INFO:     memory_info.cpp(log_usage:90): Memory Info: Finished synchronizing vertex (meta)data
# 	 Heap: 10 MB
#
# 	 Allocated: 5.9331 MB
# INFO:     distributed_ingress_base.hpp(exchange_global_info:521): Graph Finalize: exchange global statistics
#
# INFO:     distributed_ingress_base.hpp(exchange_global_info:546): Graph info:
#
# 	 nverts: 6
#
# 	 nedges: 15
#
# 	 nreplicas: 6
#
# 	 replication factor: 1
#
# INFO:     omni_engine.hpp(omni_engine:194): Using the Asynchronous engine.
#
# INFO:     distributed_graph.hpp(finalize:702): Distributed graph: enter finalize
#
# INFO:     distributed_ingress_base.hpp(finalize:199): Finalizing Graph...
#
# INFO:     distributed_ingress_base.hpp(finalize:244): Skipping Graph Finalization because no changes happened...
#
# INFO:     distributed_graph.hpp(finalize:702): Distributed graph: enter finalize
#
# INFO:     distributed_ingress_base.hpp(finalize:199): Finalizing Graph...
#
# INFO:     distributed_ingress_base.hpp(finalize:244): Skipping Graph Finalization because no changes happened...
#
# WARNING:  distributed_aggregator.hpp(test_vertex_mapper_type:344):
#
# Map Function in Vertex Aggregator find_largest_img does not pass strict runtime type checks.
#
# Function prototype should be
#
# 	 ReductionType f(icontext_type&, const vertex_type&)
#
# If you are not intentionally violating the abstraction, we recommend fixing your function for safety reasons
#
# INFO:     stitch_main.hpp(compute_features:424): Features in image #3: 295
# INFO:     stitch_main.hpp(compute_features:424): Features in image #0: 784
#
# INFO:     stitch_main.hpp(compute_features:424): Features in image #5: 1050
# INFO:     stitch_main.hpp(compute_features:424): Features in image #1: 1376
#
# INFO:     stitch_main.hpp(compute_features:424): Features in image #2: 1460
# INFO:     stitch_main.hpp(compute_features:424): Features in image #4: 1429
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (0,1): (153,98,1.81818)
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (0,2): (7,6,0.594059)
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (0,3): (30,22,1.29412)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (0,4): (93,61,1.69916)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (0,5): (109,69,1.69533)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (1,0): (153,98,1.81818)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (1,2): (226,199,2.62533)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (1,3): (6,5,0.510204)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (1,4): (222,154,2.06434)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (1,5): (31,22,1.27168)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (2,0): (7,6,0.594059)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (2,1): (226,199,2.62533)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (2,3): (14,6,0.491803)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (2,4): (138,102,2.06478)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (2,5): (8,4,0.384615)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (3,0): (30,22,1.29412)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (3,1): (6,5,0.510204)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (3,2): (14,6,0.491803)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (3,4): (4,0,0)
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (3,5): (74,41,1.35762)
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (4,0): (93,61,1.69916)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (4,1): (222,154,2.06434)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (4,2): (138,102,2.06478)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (4,3): (4,0,0)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (4,5): (123,98,2.18263)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (5,0): (109,69,1.69533)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (5,1): (31,22,1.27168)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (5,2): (8,4,0.384615)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (5,3): (74,41,1.35762)
#
# INFO:     stitch_full_main.cpp(main:205): #Matches in Pair (5,4): (123,98,2.18263)
#
# INFO:     stitch_full_main.cpp(main:235): Homography-based init, time: 0.000124595 sec
#
# INFO:     stitch_full_main.cpp(main:245): Initial intrinsics #0:
#
# [575.6492394343493, 0, 250;
#
#   0, 575.6492394343493, 167;
#
#   0, 0, 1]
#
#
#
# INFO:     stitch_full_main.cpp(main:245): Initial intrinsics #1:
#
# [575.6492394343493, 0, 250;
#
#   0, 575.6492394343493, 167;
#
#   0, 0, 1]
#
#
#
# INFO:     stitch_full_main.cpp(main:245): Initial intrinsics #2:
#
# [575.6492394343493, 0, 250;
#
#   0, 575.6492394343493, 167;
#
#   0, 0, 1]
#
#
#
# INFO:     stitch_full_main.cpp(main:245): Initial intrinsics #3:
#
# [575.6492394343493, 0, 250;
#
#   0, 575.6492394343493, 167;
#
#   0, 0, 1]
#
#
#
# INFO:     stitch_full_main.cpp(main:245): Initial intrinsics #4:
#
# [575.6492394343493, 0, 250;
#
#   0, 575.6492394343493, 167;
#
#   0, 0, 1]
#
#
#
# INFO:     stitch_full_main.cpp(main:245): Initial intrinsics #5:
#
# [575.6492394343493, 0, 250;
#
#   0, 575.6492394343493, 167;
#
#   0, 0, 1]
#
#
#
# INFO:     stitch_full_main.cpp(main:272): Bundle Adjustment, time: 0.134941 sec
#
# INFO:     stitch_full_main.cpp(main:280): Camera #0:
#
# [566.2814115254895, 0, 250;
#
#   0, 566.2814115254895, 167;
#
#   0, 0, 1]
#
#
#
# INFO:     stitch_full_main.cpp(main:280): Camera #1:
#
# [566.1777498534292, 0, 250;
#
#   0, 566.1777498534292, 167;
#
#   0, 0, 1]
#
#
#
# INFO:     stitch_full_main.cpp(main:280): Camera #2:
#
# [574.1856336755537, 0, 250;
#
#   0, 574.1856336755537, 167;
#
#   0, 0, 1]
#
#
#
# INFO:     stitch_full_main.cpp(main:280): Camera #3:
#
# [567.0110285802485, 0, 250;
#
#   0, 567.0110285802485, 167;
#
#   0, 0, 1]
#
#
#
# INFO:     stitch_full_main.cpp(main:280): Camera #4:
#
# [567.5336929994468, 0, 250;
#
#   0, 567.5336929994468, 167;
#
#   0, 0, 1]
#
#
#
# INFO:     stitch_full_main.cpp(main:280): Camera #5:
#
# [565.6048063766801, 0, 250;
#
#   0, 565.6048063766801, 167;
#
#   0, 0, 1]
#
#
#
# INFO:     distributed_graph.hpp(set_ingress_method:3201): Automatically determine ingress method: grid
#
# INFO:     stitch_main.hpp(graph_loader:168): Adding edge: (0,1)
#
# INFO:     stitch_main.hpp(graph_loader:168): Adding edge: (0,2)
#
# INFO:     stitch_main.hpp(graph_loader:168): Adding edge: (0,3)
#
# INFO:     stitch_main.hpp(graph_loader:168): Adding edge: (0,4)
#
# INFO:     stitch_main.hpp(graph_loader:168): Adding edge: (0,5)
#
# INFO:     stitch_main.hpp(graph_loader:168): Adding edge: (1,2)
#
# INFO:     stitch_main.hpp(graph_loader:168): Adding edge: (1,3)
#
# INFO:     stitch_main.hpp(graph_loader:168): Adding edge: (1,4)
#
# INFO:     stitch_main.hpp(graph_loader:168): Adding edge: (1,5)
#
# INFO:     stitch_main.hpp(graph_loader:168): Adding edge: (2,3)
#
# INFO:     stitch_main.hpp(graph_loader:168): Adding edge: (2,4)
#
# INFO:     stitch_main.hpp(graph_loader:168): Adding edge: (2,5)
#
# INFO:     stitch_main.hpp(graph_loader:168): Adding edge: (3,4)
#
# INFO:     stitch_main.hpp(graph_loader:168): Adding edge: (3,5)
#
# INFO:     stitch_main.hpp(graph_loader:168): Adding edge: (4,5)
#
# INFO:     distributed_graph.hpp(finalize:702): Distributed graph: enter finalize
#
# INFO:     distributed_ingress_base.hpp(finalize:199): Finalizing Graph...
#
# INFO:     memory_info.cpp(log_usage:90): Memory Info: Post Flush
#
# 	 Heap: 78 MB
#
# 	 Allocated: 13.2003 MB
#
# INFO:     distributed_ingress_base.hpp(finalize:259): Graph Finalize: constructing local graph
#
# INFO:     memory_info.cpp(log_usage:90): Memory Info: Finished populating local graph.
#
# 	 Heap: 78 MB
#
# 	 Allocated: 13.2123 MB
#
# INFO:     distributed_ingress_base.hpp(finalize:304): Graph Finalize: finalizing local graph.
#
# INFO:     dynamic_local_graph.hpp(finalize:339): Graph finalized in 0.061631 secs
#
# INFO:     distributed_ingress_base.hpp(finalize:307): Local graph info:
#
# 	 nverts: 6
#
# 	 nedges: 15
#
# INFO:     memory_info.cpp(log_usage:90): Memory Info: Finished finalizing local graph.
#
# 	 Heap: 78 MB
#
# 	 Allocated: 13.2142 MB
#
# INFO:     memory_info.cpp(log_usage:90): Memory Info: Finished adding vertex data
#
# 	 Heap: 78 MB
#
# 	 Allocated: 13.211 MB
#
# INFO:     memory_info.cpp(log_usage:90): Memory Info: Finihsed allocating lvid2record
#
# 	 Heap: 78 MB
#
# 	 Allocated: 13.2046 MB
#
# INFO:     memory_info.cpp(log_usage:90): Memory Info: Finished synchronizing vertex (meta)data
#
# 	 Heap: 78 MB
#
# 	 Allocated: 13.5941 MB
# INFO:     distributed_ingress_base.hpp(exchange_global_info:521): Graph Finalize: exchange global statistics
# INFO:     distributed_ingress_base.hpp(exchange_global_info:546): Graph info:
#
# 	 nverts: 6
#
# 	 nedges: 15
#
# 	 nreplicas: 6
#
# 	 replication factor: 1
#
# INFO:     omni_engine.hpp(omni_engine:194): Using the Asynchronous engine.
# INFO:     distributed_graph.hpp(finalize:702): Distributed graph: enter finalize
#
# INFO:     distributed_ingress_base.hpp(finalize:199): Finalizing Graph...
#
# INFO:     distributed_ingress_base.hpp(finalize:244): Skipping Graph Finalization because no changes happened...
#
# INFO:     distributed_graph.hpp(finalize:702): Distributed graph: enter finalize
#
# INFO:     distributed_ingress_base.hpp(finalize:199): Finalizing Graph...
#
# INFO:     distributed_ingress_base.hpp(finalize:244): Skipping Graph Finalization because no changes happened...
#
# INFO:     dc.cpp(~distributed_control:166): Shutting down distributed control
# INFO:     dc_tcp_comm.cpp(close:247): Closing listening socket
#
# INFO:     dc_tcp_comm.cpp(send_loop:653): Send loop Stopped
#
# INFO:     dc_tcp_comm.cpp(close:267): Closing outgoing sockets
#
# INFO:     dc_tcp_comm.cpp(receive_loop:594): Receive loop Stopped
#
# INFO:     dc_tcp_comm.cpp(close:285): Closing incoming sockets
#
# INFO:     dc.cpp(~distributed_control:198): Bytes Sent: 6038
#
# INFO:     dc.cpp(~distributed_control:199): Calls Sent: 4
#
# INFO:     dc.cpp(~distributed_control:200): Network Sent: 6038
#
# INFO:     dc.cpp(~distributed_control:201): Bytes Received: 6006
#
# INFO:     dc.cpp(~distributed_control:202): Calls Received: 4
#
#
# Received JobID: xhM9g4omoYMTucATxVjrJ6
# Data request from Server
# Received JobID: xhM9g4omoYMTucATxVjrJ6
# /media/pictures/2eb315c2-ae39-11e4-b6e7-22000aecbe9d/xhM9g4omoYMTucATxVjrJ6/results/result_stitch.jpg
#
# File Saved: /home/parallels/Pictures/test_download/xhM9g4omoYMTucATxVjrJ6/result_stitch.jpg
# Data Received from Server
# Exiting Redis Thread for HTTP Post requests
# Lost connection (Connection closed)
# Ending Listing to Redis Channel
#
# Socket waiting finished.
#
# Exiting Socket Connection Thread

# %%
i = Image(os.path.join(uj.job.resultpath, 'result_stitch.jpg'))
display(i)

# %%
exit
# Out:
# /home/parallels/workspace/client_env/local/lib/python2.7/site-packages/cherrypy/process/wspbus.py:233: RuntimeWarning: The main thread is exiting, but the Bus is in the states.STARTED state; shutting it down automatically now. You must either call bus.block() after start(), or call bus.exit() before the main thread exits.
#   "main thread exits." % self.state, RuntimeWarning)
# INFO:cherrypy.error:[19/Feb/2015:22:52:53] ENGINE Bus STOPPING
# INFO:cherrypy.error:[19/Feb/2015:22:52:53] ENGINE HTTP Server cherrypy._cpwsgi_server.CPWSGIServer(('127.0.0.1', 8000)) shut down
# INFO:cherrypy.error:[19/Feb/2015:22:52:53] ENGINE Stopped thread 'Autoreloader'.
# INFO:cherrypy.error:[19/Feb/2015:22:52:53] ENGINE Stopped thread '_TimeoutMonitor'.
# INFO:cherrypy.error:[19/Feb/2015:22:52:53] ENGINE Bus STOPPED
# INFO:cherrypy.error:[19/Feb/2015:22:52:53] ENGINE Bus EXITING
# INFO:cherrypy.error:[19/Feb/2015:22:52:53] ENGINE Bus EXITED
# Error in atexit._run_exitfuncs:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/atexit.py", line 24, in _run_exitfuncs
#     func(*targs, **kargs)
#   File "/home/parallels/workspace/client_env/local/lib/python2.7/site-packages/colorama/initialise.py", line 18, in reset_all
#     AnsiToWin32(orig_stdout).reset_all()
#   File "/home/parallels/workspace/client_env/local/lib/python2.7/site-packages/colorama/ansitowin32.py", line 144, in reset_all
#     elif not self.wrapped.closed and is_a_tty(self.wrapped):
# AttributeError: 'OutStream' object has no attribute 'closed'
# INFO:cherrypy.error:[19/Feb/2015:22:52:54] ENGINE Waiting for child threads to terminate...
